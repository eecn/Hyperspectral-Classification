# %% [markdown]
# <a href="https://colab.research.google.com/github/syamkakarla98/Hyperspectral_Image_Analysis_Simplified/blob/master/Articles/Hyperspectral_Image_Analysis%E2%80%8A_%E2%80%8AClassification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # <font color = 'tomato'>Hyperspectral Image Analysis - Classification</font>

# %% [markdown]
# ## Import Libraries

# %%
import plotly.express as px
import matplotlib.pyplot as plt
import seaborn as sn
import numpy as np
sn.axes_style('whitegrid');
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# %% [markdown]
# ## Read the Data

# %%
from scipy.io import loadmat

def read_HSI():
  X = loadmat('Datasets/WHUHiLongKou/WHU_Hi_LongKou.mat')['WHU_Hi_LongKou']
  y = loadmat('Datasets/WHUHiLongKou/WHU_Hi_LongKou_gt.mat')['WHU_Hi_LongKou_gt']
  print(f"X shape: {X.shape}\ny shape: {y.shape}")
  return X, y

X, y = read_HSI()
# Out:
# X shape: (550, 400, 270)
# y shape: (550, 400)

# %% [markdown]
# ### Visualize Bands

# %%
fig = plt.figure(figsize = (12, 6))

for i in range(1, 1+6):
    fig.add_subplot(2,3, i)
    q = np.random.randint(X.shape[2])
    plt.imshow(X[:,:,q], cmap='nipy_spectral')
    plt.axis('off')
    plt.title(f'Band - {q}')
plt.savefig('IP_Bands.png')

# %% [markdown]
# ### Visualize the Ground Truth

# %%
plt.figure(figsize=(10, 8))
plt.imshow(y, cmap='nipy_spectral')
plt.colorbar()
plt.axis('off')
plt.savefig('IP_GT.png')
plt.show()

# %% [markdown]
# ## Convert the dataset into csv

# %%
import pandas as pd
import numpy as np

def extract_pixels(X, y):
  q = X.reshape(-1, X.shape[2])
  df = pd.DataFrame(data = q)
  df = pd.concat([df, pd.DataFrame(data = y.ravel())], axis=1)
  df.columns= [f'band{i}' for i in range(1, 1+X.shape[2])]+['class']
  df.to_csv('Dataset.csv')
  return df
  
df = extract_pixels(X, y)

# %%
df.head()
# Out:
#       band1     band2     band3     band4     band5     band6     band7  \
# 0  0.119144  0.452328  0.589048  0.711483  0.848857  0.822307  1.020831
# 1  0.266055  0.436670  0.684605  0.708308  0.771029  0.803337  0.960599
# 2  0.135489  0.552779  0.565573  0.653725  0.708799  0.834761  0.931162
# 3  0.175765  0.616654  0.586812  0.719655  0.723561  0.866418  0.906637
# 4  0.175710  0.388793  0.595213  0.572375  0.766622  0.809911  0.911719
#
#       band8     band9    band10  ...   band262   band263   band264   band265  \
# 0  1.088326  1.143050  1.161772  ...  6.279046  6.698318  7.301254  7.696913
# 1  1.037369  1.260548  1.112069  ...  6.227319  6.497162  7.489038  7.888824
# 2  1.007277  1.115141  1.189783  ...  6.210227  6.662137  7.323027  7.773304
# 3  0.977693  1.036860  1.068036  ...  6.176208  6.670024  7.319337  7.639920
# 4  1.036256  1.195407  1.073012  ...  5.913688  6.402612  7.518503  7.206825
#
#     band266   band267   band268   band269   band270  class
# 0  8.261939  8.575315  8.633758  8.413543  8.890121      0
# 1  8.225585  8.516209  8.744693  8.196497  8.692479      0
# 2  8.328890  8.723454  8.821000  8.447286  8.567034      0
# 3  8.610709  8.163558  8.881254  8.785563  8.839517      0
# 4  7.900758  8.000796  8.446876  8.523228  8.572126      0
#
# [5 rows x 271 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 220000 entries, 0 to 219999
# Columns: 271 entries, band1 to class
# dtypes: float32(270), uint8(1)
# memory usage: 226.8 MB

# %%
df.iloc[:, :-1].describe()
# Out:
#                band1          band2          band3          band4  \
# count  220000.000000  220000.000000  220000.000000  220000.000000
# mean        0.349652       0.623932       0.782515       0.916357
# std         0.294410       0.328869       0.365944       0.382295
# min         0.001653       0.134911       0.239264       0.402063
# 25%         0.192032       0.451997       0.598411       0.721634
# 50%         0.251752       0.514855       0.661578       0.786395
# 75%         0.363692       0.628819       0.779859       0.916494
# max         5.370272       7.046251       9.133835      10.194220
#
#                band5          band6          band7          band8  \
# count  220000.000000  220000.000000  220000.000000  220000.000000
# mean        0.974940       1.080953       1.153520       1.250829
# std         0.403166       0.419552       0.458527       0.476274
# min         0.422764       0.568164       0.569339       0.715141
# 25%         0.778211       0.869239       0.928696       1.010438
# 50%         0.839404       0.935782       0.994708       1.081733
# 75%         0.961642       1.079593       1.143127       1.250063
# max        11.972128      12.760905      14.785662      15.825777
#
#                band9         band10  ...        band261        band262  \
# count  220000.000000  220000.000000  ...  220000.000000  220000.000000
# mean        1.292124       1.342294  ...       4.560478       4.768682
# std         0.503981       0.513049  ...       3.104456       3.263049
# min         0.670540       0.766432  ...       0.031237       0.026068
# 25%         1.044566       1.084552  ...       0.598137       0.587014
# 50%         1.115737       1.158916  ...       5.268698       5.519035
# 75%         1.286306       1.341924  ...       6.752411       7.091768
# max        17.799282      18.357952  ...      11.196452      11.704119
#
#              band263        band264        band265        band266  \
# count  220000.000000  220000.000000  220000.000000  220000.000000
# mean        5.053742       5.493991       5.791009       6.176594
# std         3.438814       3.757334       3.939979       4.222261
# min         0.012735       0.039985       0.043228       0.033274
# 25%         0.663678       0.669689       0.748957       0.748613
# 50%         5.832833       6.373884       6.697929       7.166096
# 75%         7.490743       8.162540       8.580380       9.175024
# max        12.418871      13.366635      14.163141      15.094628
#
#              band267        band268        band269        band270
# count  220000.000000  220000.000000  220000.000000  220000.000000
# mean        6.323003       6.526428       6.624918       6.754577
# std         4.307987       4.466509       4.488750       4.590925
# min         0.017239       0.054006       0.021927       0.093662
# 25%         0.802951       0.777289       0.867650       0.848632
# 50%         7.324158       7.576926       7.672958       7.836765
# 75%         9.366938       9.699584       9.793587      10.006351
# max        15.326093      15.847483      15.908350      16.344149
#
# [8 rows x 270 columns]

# %% [markdown]
# ## Principal Component Analysis(PCA)

# %%
from sklearn.decomposition import PCA

pca = PCA(n_components = 85)

principalComponents = pca.fit_transform(df.iloc[:, :-1].values)

ev=pca.explained_variance_ratio_

plt.figure(figsize=(12, 6))
plt.plot(np.cumsum(ev))
plt.xlabel('Number of components')
plt.ylabel('Cumulative explained variance')


plt.show()

# %% [markdown]
# Select 40 as the no.of components for PCA

# %%
pca = PCA(n_components = 40)
dt = pca.fit_transform(df.iloc[:, :-1].values)
q = pd.concat([pd.DataFrame(data = dt), pd.DataFrame(data = y.ravel())], axis = 1)
q.columns = [f'PC-{i}' for i in range(1,41)]+['class']

# %%
q.head()
# Out:
#         PC-1      PC-2      PC-3      PC-4      PC-5      PC-6      PC-7  \
# 0  27.283329 -0.634824 -2.449859  2.236468 -1.781516 -0.806394 -0.434324
# 1  24.220955 -2.413397 -3.394291  2.426874 -0.789760 -0.805992 -0.267775
# 2  19.329496 -4.833391 -5.910287  2.009513  0.192288 -0.705770 -0.085989
# 3  17.565968 -5.337728 -7.382889  2.695931  0.100099 -0.730365 -0.056959
# 4  13.552742 -8.231369 -7.652500  2.164084 -0.325431 -0.036119  0.307305
#
#        PC-8      PC-9     PC-10  ...     PC-32     PC-33     PC-34     PC-35  \
# 0 -0.375730  0.987923  0.309165  ... -0.028098  0.135041 -0.296084 -0.003911
# 1 -0.186457  0.775143  0.121813  ... -0.003827  0.060121 -0.054496  0.184394
# 2 -0.225433  0.487174  0.033705  ...  0.044259 -0.012072 -0.252969  0.135238
# 3 -0.329188  0.396913  0.029081  ...  0.062994 -0.018019 -0.042124  0.037901
# 4 -0.073921  0.415081  0.074014  ... -0.033155 -0.051842  0.038604  0.014666
#
#       PC-36     PC-37     PC-38     PC-39     PC-40  class
# 0 -0.017976 -0.132678 -0.196326  0.073068 -0.068469      0
# 1 -0.093272 -0.075167 -0.205640 -0.071998 -0.038069      0
# 2  0.072709  0.119087 -0.081999 -0.093517 -0.075426      0
# 3 -0.043820  0.083060 -0.078015 -0.067058  0.096095      0
# 4  0.036968  0.087121  0.014269  0.114967  0.083273      0
#
# [5 rows x 41 columns]

# %% [markdown]
# ### Display the bands after PCA

# %%
fig = plt.figure(figsize = (20, 10))

for i in range(1, 1+8):
    fig.add_subplot(2,4, i)
    plt.imshow(q.loc[:, f'PC-{i}'].values.reshape(y.shape[0], y.shape[1]), cmap='nipy_spectral')
    plt.axis('off')
    plt.title(f'Band - {i}')

plt.savefig('IP_PCA_Bands.png')

# %%
# saving to .csv
q.to_csv('IP_40_PCA.csv', index=False)

# %% [markdown]
# ## Support Vector Machine(SVM)

# %%
x = q[q['class'] != 0]

X = x.iloc[:, :-1].values

y = x.loc[:, 'class'].values 

names = ["Unknown",
        "Corn",
        "Cotton",
        "Sesame",
        "Broad-leaf soybean",
        "Narrow-leaf soybean",
        "Rices",
        "Water",
        "Roads and houses",
        "Mixed weed",]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=11, stratify=y)

svm =  SVC(C = 100, kernel = 'rbf', cache_size = 10*1024)

svm.fit(X_train, y_train)

ypred = svm.predict(X_test)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_5904/3823664893.py in <module>
#      13 svm =  SVC(C = 100, kernel = 'rbf', cache_size = 10*1024)
#      14
# ---> 15 svm.fit(X_train, y_train)
#      16
#      17 ypred = svm.predict(X_test)
#
# ~/anaconda3/envs/torchlatest/lib/python3.9/site-packages/sklearn/svm/_base.py in fit(self, X, y, sample_weight)
#     253
#     254         seed = rnd.randint(np.iinfo("i").max)
# --> 255         fit(X, y, sample_weight, solver_type, kernel, random_seed=seed)
#     256         # see comment on the other call to np.iinfo in this file
#     257
#
# ~/anaconda3/envs/torchlatest/lib/python3.9/site-packages/sklearn/svm/_base.py in _dense_fit(self, X, y, sample_weight, solver_type, kernel, random_seed)
#     313             self._probB,
#     314             self.fit_status_,
# --> 315         ) = libsvm.fit(
#     316             X,
#     317             y,
#
# KeyboardInterrupt:

# %%
data = confusion_matrix(y_test, ypred)
df_cm = pd.DataFrame(data, columns=np.unique(names), index = np.unique(names))
df_cm.index.name = 'Actual'
df_cm.columns.name = 'Predicted'
plt.figure(figsize = (10,8))
sn.set(font_scale=1.4)#for label size
sn.heatmap(df_cm, cmap="Reds", annot=True,annot_kws={"size": 16}, fmt='d')
plt.savefig('cmap.png', dpi=300)

# %%
print(classification_report(y_test, ypred, target_names = names))

# %% [markdown]
# ## Classification Map

# %%
l=[]
for i in range(q.shape[0]):
  if q.iloc[i, -1] == 0:
    l.append(0)
  else:
    l.append(svm.predict(q.iloc[i, :-1].values.reshape(1, -1)))

# %%
clmap = np.array(l).reshape(145, 145).astype('float')
plt.figure(figsize=(10, 8))
plt.imshow(clmap, cmap='nipy_spectral')
plt.colorbar()
plt.axis('off')
plt.savefig('IP_cmap.png')
plt.show()

# %% [markdown]
# ---
#
#
#
# ---
